// %% [markdown]
// # Laboratório em Estruturas de Programação Java
//
// O laboratório a seguir serve para praticar estruturas de programação Java sem compromisso com a orientação a objetos.

// %% [markdown]
// ## Desafio 1 - Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ### Desafio 1 / Parte 1 - Escrevendo o programa sem módulos
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * S: 200
// * N: 5
// * J: 1%
//
// Nesta versão não use outro módulo além da função principal.

// %%
double emprestimo = 200, juros = 0.01;
int numeroParcelas = 5;

for(int i = 1; i <= numeroParcelas; i++){
    System.out.println(String.format("%.2f",emprestimo));
    emprestimo = emprestimo + (juros * emprestimo);
}
// Out:
// 200.00
// 202.00
// 204.02
// 206.06
// 208.12
// null

// %% [markdown]
// ### Desafio 1 / Parte 2 - Escrevendo módulos
//
// Reescreva o código acima de forma que seu programa faça uso de uma função que seja responsável pelo cálculo de uma parcela X do empréstimo. Podem ser usadas mais funções (métodos) conforme a necessidade.

// %%
public class Emprestimo{
    static double proximaParcela(double valor, double juros){
        return valor + (juros * valor);
    }
}
// Out:
// com.twosigma.beaker.javash.bkr42b1b345.Emprestimo

// %%
double valor = 200, juros = 0.01;
int numeroParcelas = 5;

while(numeroParcelas != -1){
    System.out.println(String.format("%.2f", valor));
    valor = Emprestimo.proximaParcela(valor, juros);
    numeroParcelas--;
}
// Out:
// 200.00
// 202.00
// 204.02
// 206.06
// 208.12
// 210.20
// null

// %% [markdown]
// ## Desafio 2
//
// Escreva um programa que sorteie um número inteiro entre `0` e `9999` o número deve ser mostrado, em seguida convertido para binário e a versão binária deve ser apresentada no console. A conversão decimal/binário deve ser computada por um programa feito por você.

// %%
import java.util.Random;

Random rand = new Random();
int numero = rand.nextInt(9999);
String binario = "";

System.out.println(numero);
while(numero >= 2){
    binario += numero % 2;
    numero = (int)numero / 2;
}

if(numero == 1)
    binario += "1";

System.out.println(new StringBuilder(binario).reverse().toString());
// Out:
// 7275
// 1110001101011
// null

// %% [markdown]
// ## Desafio 3
//
// Uma molécula de DNA pode ser definida a partir de uma cadeia que representa a sequência de suas bases:
// A - Adenina
// C - Citisina
// G - Guanina
// T - Tinina
//
// Desse modo, uma string pode ser usada para representar um segmento do DNA da seguinte maneira: `ATTACGCGCAAAC`.
//
// Escreva uma função (método) que codifique a cadeia de RNA produzida a partir de uma cadeia de DNA. A função deve ser genérica o suficiente para ser aplicável a qualquer cadeia. A entrada é uma string (DNA) e o retorno é uma string (RNA).
//
// Escreva um programa que teste esta função com uma cadeia de DNA de sua escolha.

// %%
public class RNA{
    static String producao(String DNA){
        DNA = DNA.toUpperCase();
        return DNA.replace("T", "U");
    }
}
// Out:
// com.twosigma.beaker.javash.bkr42b1b345.RNA

// %%
import java.util.Scanner;

Scanner ler = new Scanner(System.in);
System.out.printf("Informe a sequência do DNA:\n");
String cadeia = ler.nextLine();

System.out.println(RNA.producao(cadeia));
// Out:
// Informe a sequência do DNA:
//  ATTACGCGCAAAC
// AUUACGCGCAAAC
// null

// %% [markdown]
// ## Desafio 4
//
// Uma empresa precisa realizar uma estatística do salário de seus funcionários.
//
// Para fins de teste, os salários devem ser gerados aleatoriamente com valores variando entre R\\$ 2.500 e R\\$ 15.000.
//
// Escreva um programa que gere uma lista contendo os salários de 50 funcionários da empresa e mostre no console quantos funcionários ganham salário acima da média.

// %%
import java.util.Random;

Random rand = new Random();
float limiteE = 2500, limiteD = 15000, media = 0;
float salarios[] = new float[50];
int qtdAcimaMedia = 0;

for(int i = 0; i <= 49; i++){
    salarios[i] = (rand.nextFloat() * (limiteD - limiteE)) + limiteE;
    media += salarios[i]/50;
    System.out.println((i+1) + "º Salário: " + String.format("%.2f", salarios[i]));
}

for(int i = 0; i <= 49; i++){
    if(salarios[i] > media)
        qtdAcimaMedia++;
}

System.out.println("Número de funcionários com salário acima da média: " + qtdAcimaMedia);
// Out:
// 1º Salário: 9294.85
// 2º Salário: 11661.51
// 3º Salário: 2751.37
// 4º Salário: 6132.56
// 5º Salário: 14449.29
// 6º Salário: 3374.89
// 7º Salário: 6239.21
// 8º Salário: 4817.02
// 9º Salário: 5591.66
// 10º Salário: 14297.26
// 11º Salário: 8954.70
// 12º Salário: 8564.90
// 13º Salário: 3128.12
// 14º Salário: 14589.81
// 15º Salário: 9330.26
// 16º Salário: 4465.05
// 17º Salário: 11128.66
// 18º Salário: 9590.28
// 19º Salário: 12389.56
// 20º Salário: 8350.81
// 21º Salário: 10881.07
// 22º Salário: 4584.28
// 23º Salário: 7015.98
// 24º Salário: 3805.86
// 25º Salário: 6455.60
// 26º Salário: 11661.43
// 27º Salário: 13658.06
// 28º Salário: 7222.73
// 29º Salário: 6426.86
// 30º Salário: 3496.65
// 31º Salário: 9437.38
// 32º Salário: 14514.33
// 33º Salário: 10766.85
// 34º Salário: 8083.73
// 35º Salário: 9070.36
// 36º Salário: 5685.72
// 37º Salário: 13239.60
// 38º Salário: 5199.61
// 39º Salário: 13385.42
// 40º Salário: 12778.09
// 41º Salário: 10852.94
// 42º Salário: 8025.53
// 43º Salário: 14505.86
// 44º Salário: 13364.90
// 45º Salário: 11242.34
// 46º Salário: 7923.81
// 47º Salário: 8759.54
// 48º Salário: 9982.88
// 49º Salário: 9814.24
// 50º Salário: 8714.25
// Número de funcionários com salário acima da média: 25
// null
